# %%
# !pip install tgan
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 273 kB 7.4 MB/s
# ...
#      |████████████████████████████████| 110.5 MB 1.6 kB/s
# ...
#      |████████████████████████████████| 20.1 MB 64.1 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 73.1 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 76.7 MB/s
# ...
#      |████████████████████████████████| 50 kB 8.0 MB/s
# ...
#      |████████████████████████████████| 503 kB 86.1 MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=695b0ef3611c27124f226cbb59ba359c44ab390864915fd9f9be0a0b62dd5ae8
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: h5py
# ...

# %%
import tgan
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/PAPER/진행연구/tabular deep learning/폐암병기/data/8. train_data _73.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1616 entries, 0 to 1615
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   a_year_time             1616 non-null   int64
#  1   a_year_event            1616 non-null   int64
#  2   gender                  1616 non-null   int64
#  3   age                     1616 non-null   int64
#  4   HEIGHT                  1616 non-null   float64
#  5   WEIGHT                  1616 non-null   float64
#  6   Smoker                  1616 non-null   int64
#  7   PackYear                1616 non-null   float64
#  8   ECOG                    1616 non-null   int64
#  9   FVC                     1616 non-null   float64
#  10  FEV1                    1616 non-null   float64
#  11  DLCO                    1616 non-null   float64
#  12  DLCO_PERCENT            1616 non-null   float64
#  13  SmallCell               1616 non-null   int64
# ...

# %%
death_df=df[(df['a_year_event']==1)]

# %%
dearh_df.shape
# Out:
# (449, 24)

# %%
death_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 449 entries, 1 to 1615
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   a_year_time             449 non-null    int64
#  1   a_year_event            449 non-null    int64
#  2   gender                  449 non-null    int64
#  3   age                     449 non-null    int64
#  4   HEIGHT                  449 non-null    float64
#  5   WEIGHT                  449 non-null    float64
#  6   Smoker                  449 non-null    int64
#  7   PackYear                449 non-null    float64
#  8   ECOG                    449 non-null    int64
#  9   FVC                     449 non-null    float64
#  10  FEV1                    449 non-null    float64
#  11  DLCO                    449 non-null    float64
#  12  DLCO_PERCENT            449 non-null    float64
#  13  SmallCell               449 non-null    int64
# ...

# %%
death_Smoker=lives_df[(lives_df['Smoker']>1) & (lives_df['PackYear']>0)]

# %%
death_Smoker.shape
# Out:
# (343, 24)

# %%
death_Smoker.to_csv('/content/drive/MyDrive/PAPER/진행연구/tabular deep learning/폐암병기/data/11.train_data_73_death_smoker.csv',index=False)

# %%
data = pd.read_csv('/content/drive/MyDrive/PAPER/진행연구/tabular deep learning/폐암병기/data/11.train_data_73_death_smoker.csv')

continuous_columns = [4,5,9,10,11]

# %%
data.shape
# Out:
# (343, 24)

# %%
'''
                        'a_year_time',
                        'a_year_event',
                        'age',
                        'Smoker',
                        'PackYear',
                        'ECOG',
                        'FVC',
                        'FEV1',
                        'DLCO',
                        'DLCO_PERCENT',
                        'SmallCellC',
                        'AdenoC',
                        'largeCellC',
                        'Positive_EGFR_Mutation',
                        'Positive_ALK_IHC',
                        'Positive_ALK_FISH',
                        'STAGE_simple',
                        'OP_Curative',
                        'RT',
                        'Chemo_curative',
                        'Chemo_Palliative'
'''

# %%
from tgan.model import TGANModel
tgan = TGANModel(continuous_columns)

# %%
'''
tgan = TGANModel(
    continuous_columns,
    output='output',
    gpu=None,
    max_epoch=5,
    steps_per_epoch=10000,
    save_checkpoints=True,
    restore_session=True,
    batch_size=100,
    z_dim=200,
    noise=0.2,
    l2norm=0.00001,
    learning_rate=0.001,
    num_gen_rnn=100,
    num_gen_feature=100,
    num_dis_layers=1,
    num_dis_hidden=100,
    optimizer='AdamOptimizer'
)
'''

# %%
tgan.fit(data)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorpack/graph_builder/model_desc.py:29: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorpack/graph_builder/model_desc.py:39: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorpack/input_source/input_source.py:219: The name tf.FIFOQueue is deprecated. Please use tf.queue.FIFOQueue instead.
# [0813 23:43:46 @input_source.py:222] Setting up the queue 'QueueInput/input_queue' for CPU prefetching ...
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorpack/tfutils/summary.py:237: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# ...

# %%
num_samples = 12000
                                                            
samples = tgan.sample(num_samples)
samples.head(3)

# %%
samples.shape
# Out:
# (13000, 24)

# %%
samples.to_csv('/content/drive/MyDrive/PAPER/진행연구/tabular deep learning/폐암병기/modeling/result data/TGAN-v7(Augmentation-small)/TGAN-syn-AR-death-Smoker_10(13000).csv', index=False)

# %%
model_path = '/content/drive/MyDrive/PAPER/진행연구/tabular deep learning/폐암병기/modeling/model-save/TGAN model saves_part4(augmentation_small)/syn_train_unbalancedAR_survival-Smoker'
tgan.save(model_path)
# Out:
# [0813 14:02:00 @model.py:813] Model saved successfully.
